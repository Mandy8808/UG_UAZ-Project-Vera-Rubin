# %%
# illustrative example of use VeraRubin

# %% [markdown]
# ## Making a custom coadd
#
# > Version: 1.0
# >
# > Container Size: Large
#
# > Description: In this notebook, we present an illustrative example of the use of the VeraRubin package, where we make a custom coadd from the lsst-distribution.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Complementary info
! echo $IMAGE_DESCRIPTION
! eups list -s | grep lsst_distrib
# Out:
# Release r29.2.0 (RSP Build 2648)
# lsst_distrib          gc675d380bf+f75de59d28 	current v29_2_0 v29_2_0_rc1 setup

# %%
# Loading modules
import numpy as np
import VeraRubin as vr

# %% [markdown]
# # Making a custom-coadd-filter

# %%
# Coordinates
# within x-degrees of RA, Dec
ra_deg, dec_deg = (53.2, -27.8)

# %%
loc_data = ra_deg, dec_deg

bands = ['g', 'r', 'i']  # alternatively, you can use 'gri'
selection = {name: ['psfSigma', 'airmass'] for name in bands}

psfSigma_cut, psfStd_cut, airmass_cut = 1.9, 0.05, 1.15

filt_cut = {
    'g': {
    'psfSigma_mean': f' <= {2.1}',
    'psfSigma_std': f' <= {psfStd_cut}',
    'airmass': f' <= {airmass_cut}'
    },
    #
    'r': {
    'psfSigma_mean': f' <= {psfSigma_cut}',
    'psfSigma_std': f' <= {psfStd_cut}',
    'airmass': f' <= {airmass_cut}'
    },
    #
    'i': {
    'psfSigma_mean': f' <= {psfSigma_cut}',
    'psfSigma_std': f' <= {psfStd_cut}',
    'airmass': f' <= {airmass_cut}'
    }
}

# Alternatively, if you can apply the same filter to all bands, you can use:
# filt_cut_select = {
#    'psfSigma_mean': f' <= {psfSigma_cut}',
#    'psfSigma_std': f' <= {psfStd_cut}',
#    'airmass': f' <= {airmass_cut}'
#}
# filt_cut = {name: filt_cut_select for name in bands}

visits_selected_list, df_metrics_list, coadd_results = vr.custom_coadd_filter(
                    loc_data=loc_data,
                    sky_coordinates=True,
                    butler=None,
                    repository="dp1",
                    collections="LSSTComCam/DP1",
                    skymap_name="lsst_cells_v1",
                    type_coadd='deep_coadd',
                    statistics={'std', 'mean'},
                    selection=selection,
                    filt_cut=filt_cut,
                    plot=True,
                    out=False,
                    my_collection_name='custom_coadd',
                    BUTLER_SAVE_PATH='local_coadd')
# Out:
# [Warning] NaNs in psfSigma_std for visit 2024121000425
# [Warning] NaNs in psfSigma_mean for visit 2024121000425
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.quantum_graph_builder</span> <span style="color: var(--jp-info-color0)">INFO</span>: Processing pipeline subgraph 1 of 1 with 4 task(s).</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.quantum_graph_builder</span> <span style="color: var(--jp-info-color0)">INFO</span>: Iterating over data ID query results.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.quantum_graph_builder</span> <span style="color: var(--jp-info-color0)">INFO</span>: Initial bipartite graph has 54 quanta, 280 dataset nodes, and 424 edges.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.quantum_graph_builder</span> <span style="color: var(--jp-info-color0)">INFO</span>: Generated 24 quanta for task makeDirectWarp.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.quantum_graph_builder</span> <span style="color: var(--jp-info-color0)">INFO</span>: Generated 24 quanta for task makePsfMatchedWarp.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.quantum_graph_builder</span> <span style="color: var(--jp-info-color0)">INFO</span>: Generated 3 quanta for task selectDeepCoaddVisits.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.quantum_graph_builder</span> <span style="color: var(--jp-info-color0)">INFO</span>: Generated 3 quanta for task assembleDeepCoadd.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.daf.butler.direct_butler._direct_butler</span> <span style="color: var(--jp-info-color0)">INFO</span>: Importing 80 datasets into Butler(collections=DirectButlerCollections(defaults=()), run=None, datastore=&#x27;file:///home/arestrada88/Alma_proyect/local_coadd/&#x27;, registry=&#x27;SQLite3@/home/arestrada88/Alma_proyect/local_coadd/gen3.sqlite3&#x27;)</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Preparing execution of quantum for label=makeDirectWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024110800249, band: &#x27;i&#x27;, day_obs: 20241108, physical_filter: &#x27;i_06&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Constructing task and executing quantum for label=makeDirectWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024110800249, band: &#x27;i&#x27;, day_obs: 20241108, physical_filter: &#x27;i_06&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeDirectWarp.select</span> <span style="color: var(--jp-info-color0)">INFO</span>: Selecting calexp {instrument: &#x27;LSSTComCam&#x27;, detector: 2, visit: 2024110800249, band: &#x27;i&#x27;, day_obs: 20241108, physical_filter: &#x27;i_06&#x27;}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeDirectWarp.select</span> <span style="color: var(--jp-info-color0)">INFO</span>: Selecting calexp {instrument: &#x27;LSSTComCam&#x27;, detector: 5, visit: 2024110800249, band: &#x27;i&#x27;, day_obs: 20241108, physical_filter: &#x27;i_06&#x27;}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Execution of task &#x27;makeDirectWarp&#x27; on quantum {instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024110800249, band: &#x27;i&#x27;, day_obs: 20241108, physical_filter: &#x27;i_06&#x27;} took 9.029 seconds</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Preparing execution of quantum for label=makeDirectWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024110800269, band: &#x27;i&#x27;, day_obs: 20241108, physical_filter: &#x27;i_06&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Constructing task and executing quantum for label=makeDirectWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024110800269, band: &#x27;i&#x27;, day_obs: 20241108, physical_filter: &#x27;i_06&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeDirectWarp.select</span> <span style="color: var(--jp-info-color0)">INFO</span>: Selecting calexp {instrument: &#x27;LSSTComCam&#x27;, detector: 4, visit: 2024110800269, band: &#x27;i&#x27;, day_obs: 20241108, physical_filter: &#x27;i_06&#x27;}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeDirectWarp.select</span> <span style="color: var(--jp-info-color0)">INFO</span>: Selecting calexp {instrument: &#x27;LSSTComCam&#x27;, detector: 5, visit: 2024110800269, band: &#x27;i&#x27;, day_obs: 20241108, physical_filter: &#x27;i_06&#x27;}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeDirectWarp.select</span> <span style="color: var(--jp-info-color0)">INFO</span>: Selecting calexp {instrument: &#x27;LSSTComCam&#x27;, detector: 8, visit: 2024110800269, band: &#x27;i&#x27;, day_obs: 20241108, physical_filter: &#x27;i_06&#x27;}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Execution of task &#x27;makeDirectWarp&#x27; on quantum {instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024110800269, band: &#x27;i&#x27;, day_obs: 20241108, physical_filter: &#x27;i_06&#x27;} took 16.344 seconds</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Preparing execution of quantum for label=makeDirectWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024120500054, band: &#x27;r&#x27;, day_obs: 20241205, physical_filter: &#x27;r_03&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Constructing task and executing quantum for label=makeDirectWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024120500054, band: &#x27;r&#x27;, day_obs: 20241205, physical_filter: &#x27;r_03&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeDirectWarp.select</span> <span style="color: var(--jp-info-color0)">INFO</span>: Selecting calexp {instrument: &#x27;LSSTComCam&#x27;, detector: 2, visit: 2024120500054, band: &#x27;r&#x27;, day_obs: 20241205, physical_filter: &#x27;r_03&#x27;}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeDirectWarp.select</span> <span style="color: var(--jp-info-color0)">INFO</span>: Selecting calexp {instrument: &#x27;LSSTComCam&#x27;, detector: 5, visit: 2024120500054, band: &#x27;r&#x27;, day_obs: 20241205, physical_filter: &#x27;r_03&#x27;}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Execution of task &#x27;makeDirectWarp&#x27; on quantum {instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024120500054, band: &#x27;r&#x27;, day_obs: 20241205, physical_filter: &#x27;r_03&#x27;} took 10.933 seconds</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Preparing execution of quantum for label=makeDirectWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024112900235, band: &#x27;r&#x27;, day_obs: 20241129, physical_filter: &#x27;r_03&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Constructing task and executing quantum for label=makeDirectWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024112900235, band: &#x27;r&#x27;, day_obs: 20241129, physical_filter: &#x27;r_03&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeDirectWarp.select</span> <span style="color: var(--jp-info-color0)">INFO</span>: Selecting calexp {instrument: &#x27;LSSTComCam&#x27;, detector: 5, visit: 2024112900235, band: &#x27;r&#x27;, day_obs: 20241129, physical_filter: &#x27;r_03&#x27;}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Execution of task &#x27;makeDirectWarp&#x27; on quantum {instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024112900235, band: &#x27;r&#x27;, day_obs: 20241129, physical_filter: &#x27;r_03&#x27;} took 3.997 seconds</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Preparing execution of quantum for label=makeDirectWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024110800250, band: &#x27;r&#x27;, day_obs: 20241108, physical_filter: &#x27;r_03&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Constructing task and executing quantum for label=makeDirectWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024110800250, band: &#x27;r&#x27;, day_obs: 20241108, physical_filter: &#x27;r_03&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeDirectWarp.select</span> <span style="color: var(--jp-info-color0)">INFO</span>: Selecting calexp {instrument: &#x27;LSSTComCam&#x27;, detector: 2, visit: 2024110800250, band: &#x27;r&#x27;, day_obs: 20241108, physical_filter: &#x27;r_03&#x27;}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeDirectWarp.select</span> <span style="color: var(--jp-info-color0)">INFO</span>: Selecting calexp {instrument: &#x27;LSSTComCam&#x27;, detector: 5, visit: 2024110800250, band: &#x27;r&#x27;, day_obs: 20241108, physical_filter: &#x27;r_03&#x27;}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Execution of task &#x27;makeDirectWarp&#x27; on quantum {instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024110800250, band: &#x27;r&#x27;, day_obs: 20241108, physical_filter: &#x27;r_03&#x27;} took 9.059 seconds</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Preparing execution of quantum for label=makeDirectWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024120500089, band: &#x27;g&#x27;, day_obs: 20241205, physical_filter: &#x27;g_01&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Constructing task and executing quantum for label=makeDirectWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024120500089, band: &#x27;g&#x27;, day_obs: 20241205, physical_filter: &#x27;g_01&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeDirectWarp.select</span> <span style="color: var(--jp-info-color0)">INFO</span>: Selecting calexp {instrument: &#x27;LSSTComCam&#x27;, detector: 2, visit: 2024120500089, band: &#x27;g&#x27;, day_obs: 20241205, physical_filter: &#x27;g_01&#x27;}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeDirectWarp.select</span> <span style="color: var(--jp-info-color0)">INFO</span>: Selecting calexp {instrument: &#x27;LSSTComCam&#x27;, detector: 5, visit: 2024120500089, band: &#x27;g&#x27;, day_obs: 20241205, physical_filter: &#x27;g_01&#x27;}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Execution of task &#x27;makeDirectWarp&#x27; on quantum {instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024120500089, band: &#x27;g&#x27;, day_obs: 20241205, physical_filter: &#x27;g_01&#x27;} took 12.573 seconds</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Preparing execution of quantum for label=makeDirectWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024120500069, band: &#x27;i&#x27;, day_obs: 20241205, physical_filter: &#x27;i_06&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Constructing task and executing quantum for label=makeDirectWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024120500069, band: &#x27;i&#x27;, day_obs: 20241205, physical_filter: &#x27;i_06&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeDirectWarp.select</span> <span style="color: var(--jp-info-color0)">INFO</span>: Selecting calexp {instrument: &#x27;LSSTComCam&#x27;, detector: 8, visit: 2024120500069, band: &#x27;i&#x27;, day_obs: 20241205, physical_filter: &#x27;i_06&#x27;}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Execution of task &#x27;makeDirectWarp&#x27; on quantum {instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024120500069, band: &#x27;i&#x27;, day_obs: 20241205, physical_filter: &#x27;i_06&#x27;} took 4.611 seconds</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Preparing execution of quantum for label=makeDirectWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024110800245, band: &#x27;i&#x27;, day_obs: 20241108, physical_filter: &#x27;i_06&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Constructing task and executing quantum for label=makeDirectWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024110800245, band: &#x27;i&#x27;, day_obs: 20241108, physical_filter: &#x27;i_06&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeDirectWarp.select</span> <span style="color: var(--jp-info-color0)">INFO</span>: Selecting calexp {instrument: &#x27;LSSTComCam&#x27;, detector: 1, visit: 2024110800245, band: &#x27;i&#x27;, day_obs: 20241108, physical_filter: &#x27;i_06&#x27;}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeDirectWarp.select</span> <span style="color: var(--jp-info-color0)">INFO</span>: Selecting calexp {instrument: &#x27;LSSTComCam&#x27;, detector: 2, visit: 2024110800245, band: &#x27;i&#x27;, day_obs: 20241108, physical_filter: &#x27;i_06&#x27;}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeDirectWarp.select</span> <span style="color: var(--jp-info-color0)">INFO</span>: Selecting calexp {instrument: &#x27;LSSTComCam&#x27;, detector: 5, visit: 2024110800245, band: &#x27;i&#x27;, day_obs: 20241108, physical_filter: &#x27;i_06&#x27;}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Execution of task &#x27;makeDirectWarp&#x27; on quantum {instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024110800245, band: &#x27;i&#x27;, day_obs: 20241108, physical_filter: &#x27;i_06&#x27;} took 15.428 seconds</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Preparing execution of quantum for label=makeDirectWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024120500064, band: &#x27;i&#x27;, day_obs: 20241205, physical_filter: &#x27;i_06&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Constructing task and executing quantum for label=makeDirectWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024120500064, band: &#x27;i&#x27;, day_obs: 20241205, physical_filter: &#x27;i_06&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeDirectWarp.select</span> <span style="color: var(--jp-info-color0)">INFO</span>: Selecting calexp {instrument: &#x27;LSSTComCam&#x27;, detector: 5, visit: 2024120500064, band: &#x27;i&#x27;, day_obs: 20241205, physical_filter: &#x27;i_06&#x27;}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Execution of task &#x27;makeDirectWarp&#x27; on quantum {instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024120500064, band: &#x27;i&#x27;, day_obs: 20241205, physical_filter: &#x27;i_06&#x27;} took 3.813 seconds</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Preparing execution of quantum for label=makeDirectWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024110800271, band: &#x27;i&#x27;, day_obs: 20241108, physical_filter: &#x27;i_06&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Constructing task and executing quantum for label=makeDirectWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024110800271, band: &#x27;i&#x27;, day_obs: 20241108, physical_filter: &#x27;i_06&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeDirectWarp.select</span> <span style="color: var(--jp-info-color0)">INFO</span>: Selecting calexp {instrument: &#x27;LSSTComCam&#x27;, detector: 1, visit: 2024110800271, band: &#x27;i&#x27;, day_obs: 20241108, physical_filter: &#x27;i_06&#x27;}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeDirectWarp.select</span> <span style="color: var(--jp-info-color0)">INFO</span>: Selecting calexp {instrument: &#x27;LSSTComCam&#x27;, detector: 2, visit: 2024110800271, band: &#x27;i&#x27;, day_obs: 20241108, physical_filter: &#x27;i_06&#x27;}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeDirectWarp.select</span> <span style="color: var(--jp-info-color0)">INFO</span>: Selecting calexp {instrument: &#x27;LSSTComCam&#x27;, detector: 5, visit: 2024110800271, band: &#x27;i&#x27;, day_obs: 20241108, physical_filter: &#x27;i_06&#x27;}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Execution of task &#x27;makeDirectWarp&#x27; on quantum {instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024110800271, band: &#x27;i&#x27;, day_obs: 20241108, physical_filter: &#x27;i_06&#x27;} took 15.757 seconds</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Preparing execution of quantum for label=makeDirectWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024112900211, band: &#x27;r&#x27;, day_obs: 20241129, physical_filter: &#x27;r_03&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Constructing task and executing quantum for label=makeDirectWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024112900211, band: &#x27;r&#x27;, day_obs: 20241129, physical_filter: &#x27;r_03&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeDirectWarp.select</span> <span style="color: var(--jp-info-color0)">INFO</span>: Selecting calexp {instrument: &#x27;LSSTComCam&#x27;, detector: 2, visit: 2024112900211, band: &#x27;r&#x27;, day_obs: 20241129, physical_filter: &#x27;r_03&#x27;}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeDirectWarp.select</span> <span style="color: var(--jp-info-color0)">INFO</span>: Selecting calexp {instrument: &#x27;LSSTComCam&#x27;, detector: 5, visit: 2024112900211, band: &#x27;r&#x27;, day_obs: 20241129, physical_filter: &#x27;r_03&#x27;}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Execution of task &#x27;makeDirectWarp&#x27; on quantum {instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024112900211, band: &#x27;r&#x27;, day_obs: 20241129, physical_filter: &#x27;r_03&#x27;} took 13.359 seconds</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Preparing execution of quantum for label=makeDirectWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024120500065, band: &#x27;i&#x27;, day_obs: 20241205, physical_filter: &#x27;i_06&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Constructing task and executing quantum for label=makeDirectWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024120500065, band: &#x27;i&#x27;, day_obs: 20241205, physical_filter: &#x27;i_06&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeDirectWarp.select</span> <span style="color: var(--jp-info-color0)">INFO</span>: Selecting calexp {instrument: &#x27;LSSTComCam&#x27;, detector: 1, visit: 2024120500065, band: &#x27;i&#x27;, day_obs: 20241205, physical_filter: &#x27;i_06&#x27;}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeDirectWarp.select</span> <span style="color: var(--jp-info-color0)">INFO</span>: Selecting calexp {instrument: &#x27;LSSTComCam&#x27;, detector: 2, visit: 2024120500065, band: &#x27;i&#x27;, day_obs: 20241205, physical_filter: &#x27;i_06&#x27;}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeDirectWarp.select</span> <span style="color: var(--jp-info-color0)">INFO</span>: Selecting calexp {instrument: &#x27;LSSTComCam&#x27;, detector: 5, visit: 2024120500065, band: &#x27;i&#x27;, day_obs: 20241205, physical_filter: &#x27;i_06&#x27;}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Execution of task &#x27;makeDirectWarp&#x27; on quantum {instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024120500065, band: &#x27;i&#x27;, day_obs: 20241205, physical_filter: &#x27;i_06&#x27;} took 16.365 seconds</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Preparing execution of quantum for label=makeDirectWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024120500060, band: &#x27;g&#x27;, day_obs: 20241205, physical_filter: &#x27;g_01&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Constructing task and executing quantum for label=makeDirectWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024120500060, band: &#x27;g&#x27;, day_obs: 20241205, physical_filter: &#x27;g_01&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeDirectWarp.select</span> <span style="color: var(--jp-info-color0)">INFO</span>: Selecting calexp {instrument: &#x27;LSSTComCam&#x27;, detector: 5, visit: 2024120500060, band: &#x27;g&#x27;, day_obs: 20241205, physical_filter: &#x27;g_01&#x27;}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeDirectWarp.select</span> <span style="color: var(--jp-info-color0)">INFO</span>: Selecting calexp {instrument: &#x27;LSSTComCam&#x27;, detector: 8, visit: 2024120500060, band: &#x27;g&#x27;, day_obs: 20241205, physical_filter: &#x27;g_01&#x27;}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Execution of task &#x27;makeDirectWarp&#x27; on quantum {instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024120500060, band: &#x27;g&#x27;, day_obs: 20241205, physical_filter: &#x27;g_01&#x27;} took 11.202 seconds</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Preparing execution of quantum for label=makeDirectWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024120500066, band: &#x27;i&#x27;, day_obs: 20241205, physical_filter: &#x27;i_06&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Constructing task and executing quantum for label=makeDirectWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024120500066, band: &#x27;i&#x27;, day_obs: 20241205, physical_filter: &#x27;i_06&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeDirectWarp.select</span> <span style="color: var(--jp-info-color0)">INFO</span>: Selecting calexp {instrument: &#x27;LSSTComCam&#x27;, detector: 2, visit: 2024120500066, band: &#x27;i&#x27;, day_obs: 20241205, physical_filter: &#x27;i_06&#x27;}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeDirectWarp.select</span> <span style="color: var(--jp-info-color0)">INFO</span>: Selecting calexp {instrument: &#x27;LSSTComCam&#x27;, detector: 5, visit: 2024120500066, band: &#x27;i&#x27;, day_obs: 20241205, physical_filter: &#x27;i_06&#x27;}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Execution of task &#x27;makeDirectWarp&#x27; on quantum {instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024120500066, band: &#x27;i&#x27;, day_obs: 20241205, physical_filter: &#x27;i_06&#x27;} took 13.557 seconds</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Preparing execution of quantum for label=makeDirectWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024120300135, band: &#x27;g&#x27;, day_obs: 20241203, physical_filter: &#x27;g_01&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Constructing task and executing quantum for label=makeDirectWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024120300135, band: &#x27;g&#x27;, day_obs: 20241203, physical_filter: &#x27;g_01&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeDirectWarp.select</span> <span style="color: var(--jp-info-color0)">INFO</span>: Selecting calexp {instrument: &#x27;LSSTComCam&#x27;, detector: 1, visit: 2024120300135, band: &#x27;g&#x27;, day_obs: 20241203, physical_filter: &#x27;g_01&#x27;}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeDirectWarp.select</span> <span style="color: var(--jp-info-color0)">INFO</span>: Selecting calexp {instrument: &#x27;LSSTComCam&#x27;, detector: 2, visit: 2024120300135, band: &#x27;g&#x27;, day_obs: 20241203, physical_filter: &#x27;g_01&#x27;}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeDirectWarp.select</span> <span style="color: var(--jp-info-color0)">INFO</span>: Selecting calexp {instrument: &#x27;LSSTComCam&#x27;, detector: 4, visit: 2024120300135, band: &#x27;g&#x27;, day_obs: 20241203, physical_filter: &#x27;g_01&#x27;}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeDirectWarp.select</span> <span style="color: var(--jp-info-color0)">INFO</span>: Selecting calexp {instrument: &#x27;LSSTComCam&#x27;, detector: 5, visit: 2024120300135, band: &#x27;g&#x27;, day_obs: 20241203, physical_filter: &#x27;g_01&#x27;}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Execution of task &#x27;makeDirectWarp&#x27; on quantum {instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024120300135, band: &#x27;g&#x27;, day_obs: 20241203, physical_filter: &#x27;g_01&#x27;} took 18.077 seconds</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# ...
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd.detect</span> <span style="color: var(--jp-info-color0)">INFO</span>: Detected 12 positive peaks in 10 footprints and 2 negative peaks in 2 footprints to 5 +ve and 5 -ve sigma</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd</span> <span style="color: var(--jp-info-color0)">INFO</span>: Assembling 9 deepCoadd_directWarp</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 8800), maximum=(15199, 8899))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 8900), maximum=(15199, 8999))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 9000), maximum=(15199, 9099))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 9100), maximum=(15199, 9199))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 9200), maximum=(15199, 9299))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 9300), maximum=(15199, 9399))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 9400), maximum=(15199, 9499))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 9500), maximum=(15199, 9599))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 9600), maximum=(15199, 9699))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 9700), maximum=(15199, 9799))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 9800), maximum=(15199, 9899))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 9900), maximum=(15199, 9999))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 10000), maximum=(15199, 10099))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 10100), maximum=(15199, 10199))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 10200), maximum=(15199, 10299))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 10300), maximum=(15199, 10399))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 10400), maximum=(15199, 10499))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 10500), maximum=(15199, 10599))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 10600), maximum=(15199, 10699))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 10700), maximum=(15199, 10799))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 10800), maximum=(15199, 10899))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 10900), maximum=(15199, 10999))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 11000), maximum=(15199, 11099))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 11100), maximum=(15199, 11199))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 11200), maximum=(15199, 11299))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 11300), maximum=(15199, 11399))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 11400), maximum=(15199, 11499))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 11500), maximum=(15199, 11599))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 11600), maximum=(15199, 11699))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 11700), maximum=(15199, 11799))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 11800), maximum=(15199, 11899))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 11900), maximum=(15199, 11999))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 12000), maximum=(15199, 12099))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 12100), maximum=(15199, 12199))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd.interpImage</span> <span style="color: var(--jp-info-color0)">INFO</span>: Creating psf model for interpolation from fwhm(pixels) = 3.0 [default]</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd.interpImage</span> <span style="color: var(--jp-info-color0)">INFO</span>: fallbackValueType MEDIAN has been set to 0.3261</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd.interpImage</span> <span style="color: var(--jp-info-color0)">INFO</span>: Interpolated over 116 NO_DATA pixels.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Execution of task &#x27;assembleDeepCoadd&#x27; on quantum {band: &#x27;r&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34} took 118.765 seconds</pre>
# [INFO] Metadata saved: local_coadd/custom_coadd_info.txt
